# %%
alunos = ["Joao", "Maria", "Joana", "Dunha"]

print (alunos [0])
print (alunos [1])
print (alunos [-1])

alunos.append ("Gilsa")

print (alunos)

alunos.append ("Gilsa")
# Out:
# Joao
# Maria
# Dunha
# ['Joao', 'Maria', 'Joana', 'Dunha', 'Gilsa']
