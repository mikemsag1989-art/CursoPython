# %%
palavra1 = input("Digite a primeira palavra: ")
palavra2 = input("Digite a segunda palavra: ")

concat = palavra1 + ' ' + palavra2

print(f"As palavras concatenadas ficaram assim:", concat) 

print (concat.upper())
print (concat.lower())

print (len(concat))
# Out:
# Digite a primeira palavra:  uva
# Digite a segunda palavra:  passa
# As palavras concatenadas ficaram assim: uva passa
# UVA PASSA
# uva passa
# 9
